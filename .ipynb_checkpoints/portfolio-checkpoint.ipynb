# %%
import yahoo_fin.stock_info as si
import pandas as pd
from pandas_datareader import data
import datetime as dt
import matplotlib.pyplot as plt
import yfinance as yf
from yahoofinancials import YahooFinancials
import ta

# %%
# Define the instruments to download. We would like to see Apple, Microsoft and the S&P500 index.
tickers = ['D05.SI', '2846.HK', 'VUSA.L', 'VFEM.L']

# We would like all available data from 01/01/2000 until 12/31/2016.
start_date = '2015-01-01'
end_date = dt.datetime.today()

# User pandas_reader.data.DataReader to load the desired data. As simple as that.
# panel_data = data.DataReader(tickers, 'yahoo', start_date, end_date)

# %%
# close = panel_data['Close']
# all_weekdays = pd.date_range(start=start_date, end=end_date, freq='B')
# close = close.reindex(all_weekdays)
# close = close.fillna(method='ffill')

# %%
# d05 = close.loc[:, 'D05.SI']

# # Calculate the 20 and 100 days moving averages of the closing prices
# short_rolling_d05 = d05.rolling(window=20).mean()
# medium_rolling_d05 = d05.rolling(window=50).mean()
# long_rolling_d05 = d05.rolling(window=100).mean()

# # Plot everything by leveraging the very powerful matplotlib package
# fig, ax = plt.subplots(figsize=(16,9))

# ax.plot(d05.index, d05, label='D05.SI')
# ax.plot(short_rolling_d05.index, short_rolling_d05, label='20 days rolling')
# ax.plot(medium_rolling_d05.index, medium_rolling_d05, label='50 days rolling')
# ax.plot(long_rolling_d05.index, long_rolling_d05, label='100 days rolling')

# ax.set_xlabel('Date')
# ax.set_ylabel('Adjusted closing price ($)')
# ax.legend()
# plt.show()

# %%
prices_df = yf.download(tickers, 
                      start=start_date, 
                      end=end_date, 
                      progress=False)
prices_df.head()
# Out:
#             Adj Close                                       Close             \
#               2846.HK     D05.SI     VFEM.L     VUSA.L    2846.HK     D05.SI
# Date
# 2015-01-02  24.506187  16.258789  29.501879  22.841530  27.049999  20.500000
# 2015-01-05  25.140358  15.893955  29.325842  22.742615  27.750000  20.040001
# 2015-01-06  25.049761  15.727403  29.270023  22.643692  27.650000  19.830000
# 2015-01-07  25.095060  15.703609  29.896898  22.859514  27.700001  19.799999
# 2015-01-08  24.642082  15.925679  30.601059  23.309151  27.200001  20.080000
#
#                                        High             ...        Low  \
#                VFEM.L     VUSA.L    2846.HK     D05.SI  ...     VFEM.L
# Date                                                    ...
# 2015-01-02  34.355000  25.400000  27.049999  20.629999  ...  34.105099
# 2015-01-05  34.150002  25.290001  28.100000  20.389999  ...  34.099998
# 2015-01-06  34.084999  25.180000  27.950001  19.870001  ...  33.996799
# ...

# %%
close_df = prices_df['Adj Close']
all_weekdays = pd.date_range(start=start_date, end=end_date, freq='B')
close_df = close_df.reindex(all_weekdays)
close_df = close_df.fillna(method='ffill')

# %%
d05 = close_df.loc[:, 'D05.SI']

# Calculate the 20 and 100 days moving averages of the closing prices
short_rolling_d05 = d05.rolling(window=20).mean()
medium_rolling_d05 = d05.rolling(window=50).mean()
long_rolling_d05 = d05.rolling(window=100).mean()

# Plot everything by leveraging the very powerful matplotlib package
fig, ax = plt.subplots(figsize=(16,9))

ax.plot(d05.index, d05, label='D05.SI')
ax.plot(short_rolling_d05.index, short_rolling_d05, label='20 days rolling')
ax.plot(medium_rolling_d05.index, medium_rolling_d05, label='50 days rolling')
ax.plot(long_rolling_d05.index, long_rolling_d05, label='100 days rolling')

ax.set_xlabel('Date')
ax.set_ylabel('Adjusted closing price ($)')
ax.legend()
plt.show()

# %%
# assets = ['D05.SI', '2846.HK', 'VUSA.L', 'VFEM.L']

# yahoo_financials = YahooFinancials(assets)

# data = yahoo_financials.get_historical_price_data(start_date='2019-01-01', 
#                                                   end_date=str(end_date.date()), 
#                                                   time_interval='daily')

# prices_df = pd.DataFrame({
#     a: {x['formatted_date']: x['adjclose'] for x in data[a]['prices']} for a in assets
# })

# %%
d05_df = yf.download(tickers[0], 
                      start=start_date, 
                      end=end_date, 
                      progress=False)
d05_df.head()
# Out:
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2015-01-02  20.590000  20.629999  20.459999  20.500000  16.258789  1518000
# 2015-01-05  20.360001  20.389999  20.000000  20.040001  15.893955  3922000
# 2015-01-06  19.850000  19.870001  19.740000  19.830000  15.727403  5156000
# 2015-01-07  19.820000  19.920000  19.620001  19.799999  15.703609  3995000
# 2015-01-08  19.809999  20.120001  19.770000  20.080000  15.925679  4476000

# %%
# Add ta features filling NaN values
d05_df = ta.add_all_ta_features(
    d05_df, open="Open", high="High", low="Low", close="Close", volume="Volume", fillna=True)

# %%
all_weekdays = pd.date_range(start=start_date, end=end_date, freq='B')
d05_df = d05_df.reindex(all_weekdays)
d05_df = d05_df.fillna(method='ffill')

# %%
d05_df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'volume_adi',
#        'volume_obv', 'volume_cmf', 'volume_fi', 'momentum_mfi', 'volume_em',
#        'volume_sma_em', 'volume_vpt', 'volume_nvi', 'volume_vwap',
#        'volatility_atr', 'volatility_bbm', 'volatility_bbh', 'volatility_bbl',
#        'volatility_bbw', 'volatility_bbp', 'volatility_bbhi',
#        'volatility_bbli', 'volatility_kcc', 'volatility_kch', 'volatility_kcl',
#        'volatility_kcw', 'volatility_kcp', 'volatility_kchi',
#        'volatility_kcli', 'volatility_dcl', 'volatility_dch', 'trend_macd',
#        'trend_macd_signal', 'trend_macd_diff', 'trend_sma_fast',
#        'trend_sma_slow', 'trend_ema_fast', 'trend_ema_slow', 'trend_adx',
#        'trend_adx_pos', 'trend_adx_neg', 'trend_vortex_ind_pos',
#        'trend_vortex_ind_neg', 'trend_vortex_ind_diff', 'trend_trix',
#        'trend_mass_index', 'trend_cci', 'trend_dpo', 'trend_kst',
# ...

# %%
class TrackPortfolio:
    
    def __init__(self, ticker, indicators, start_date, end_date):
        self._ticker = ticker
        self._indicators = indicators
        self._start_date = start_date
        self._end_date = end_date

    def dl_data(self):
        df = yf.download(self._ticker, 
                              start=self._start_date, 
                              end=self._end_date, 
                              progress=False)
        df = ta.add_all_ta_features(
            df, open="Open", high="High", low="Low", close="Close", volume="Volume", fillna=True)
        all_weekdays = pd.date_range(start=start_date, end=end_date, freq='B')
        df = df.reindex(all_weekdays)
        self._df = df.fillna(method='ffill')
        
    def plot_chart(self):
        fig, ax = plt.subplots(figsize=(16,9))
        for i in self._indicators:
            j = self._df.loc[:,i]
            ax.plot(j.index, j, label= i)
        ax.set_xlabel('Date')
        ax.set_ylabel(self._ticker)
        ax.legend()
        plt.show()

# %%
indicators_bb = ['Close', 'volatility_bbh', 'volatility_bbm', 'volatility_bbl']
indicators_ma = ['Close', 'trend_sma_fast', 'trend_sma_slow', 'trend_ema_fast', 'trend_ema_slow']

# %%
start_date = '2015-01-01'
end_date = dt.datetime.today()

# %%
d05 = TrackPortfolio('OV8.SI', indicators_bb, start_date, end_date)
d05_df = d05.dl_data()
d05.plot_chart()

# %%
close = d05_df.loc[:, 'Close']
volatility_bbh = d05_df.loc[:, 'volatility_bbh']
volatility_bbm = d05_df.loc[:, 'volatility_bbm']
volatility_bbl = d05_df.loc[:, 'volatility_bbl']

# Plot everything by leveraging the very powerful matplotlib package
fig, ax = plt.subplots(figsize=(16,9))

ax.plot(adjclose.index, adjclose, label='Close')
ax.plot(volatility_bbh.index, volatility_bbh, label='volatility_bbh')
ax.plot(volatility_bbm.index, volatility_bbm, label= 'volatility_bbm')
ax.plot(volatility_bbl.index, volatility_bbl, label= 'volatility_bbl')

ax.set_xlabel('Date')
ax.set_ylabel('D05')
ax.legend()
plt.show()
